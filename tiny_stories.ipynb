# %% [markdown]
# <a href="https://colab.research.google.com/github/edtallison/interp-notebooks/blob/main/tiny_stories.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from transformers import AutoModelForCausalLM, AutoTokenizer, GenerationConfig
model = AutoModelForCausalLM.from_pretrained('roneneldan/TinyStories-1M')
tokenizer = AutoTokenizer.from_pretrained("EleutherAI/gpt-neo-125M")

prompt = "Once upon a time there was"

input_ids = tokenizer.encode(prompt, return_tensors="pt")
# Generate completion
output = model.generate(input_ids, max_length = 1000, num_beams=1)
# Decode the completion
output_text = tokenizer.decode(output[0], skip_special_tokens=True)
# Print the generated text
print(output_text)
# Out:
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# config.json:   0%|          | 0.00/1.02k [00:00<?, ?B/s]
# pytorch_model.bin: reconstructing file:   0%|          |  0.00B / 48.6MB
# pytorch_model.bin: downloading bytes:           |  0.00B
# Loading weights:   0%|          | 0/108 [00:00<?, ?it/s]
# model.safetensors: reconstructing file:   0%|          |  0.00B / 48.6MB
# model.safetensors: downloading bytes:           |  0.00B
# [transformers] GPTNeoForCausalLM LOAD REPORT from: roneneldan/TinyStories-1M
# Key                                                               | Status     |  |
# ------------------------------------------------------------------+------------+--+-
# transformer.h.{0, 1, 2, 3, 4, 5, 6, 7}.attn.attention.masked_bias | UNEXPECTED |  |
# transformer.h.{0, 1, 2, 3, 4, 5, 6, 7}.attn.attention.bias        | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED:	can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# config.json:   0%|          | 0.00/1.01k [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/727 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/899k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/357 [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/2.11M [00:00<?, ?B/s]
# [transformers] Ignoring clean_up_tokenization_spaces=True for BPE tokenizer GPT2Tokenizer. The clean_up_tokenization post-processing step is designed for WordPiece tokenizers and is destructive for BPE (it strips spaces before punctuation). Set clean_up_tokenization_spaces=False to suppress this warning, or set clean_up_tokenization_spaces_for_bpe_even_though_it_will_corrupt_output=True to force cleanup anyway.
# Once upon a time there was a little girl named Lily. She loved to play outside in the sunshine. One day, she saw a big, shiny rock in the sky. She wanted to touch it, but it was too high.
#
# Lily's mommy told her that it was important to be careful and not touch things. Lily didn't want to touch it, so she asked her mommy if she could touch it. Her mommy said yes and they went to the park.
#
# When they got there, Lily saw a big, scary dog. The dog was barking and barked loudly. Lily was scared and didn't know what to do. She tried to run away, but she was too fast. She tried to run away, but it was too late. The dog was too fast and it was too fast.
#
# Lily was sad and cried. She wished she had listened to her mommy. She wished she had listened to her mommy and never let her to get back.

# %%
print(model.config)
# Out:
# GPTNeoConfig {
#   "activation_function": "gelu_new",
#   "architectures": [
#     "GPTNeoForCausalLM"
#   ],
#   "attention_dropout": 0,
#   "attention_layers": [
#     "global",
#     "local",
#     "global",
#     "local",
#     "global",
#     "local",
#     "global",
#     "local"
#   ],
#   "attention_types": [
#     [
#       [
#         "global",
#         "local"
#       ],
#       4
#     ]
#   ],
#   "bos_token_id": 50256,
#   "classifier_dropout": 0.1,
#   "dtype": "float32",
#   "embed_dropout": 0,
#   "eos_token_id": 50256,
#   "gradient_checkpointing": false,
#   "hidden_size": 64,
#   "initializer_range": 0.02,
#   "intermediate_size": null,
#   "layer_norm_epsilon": 1e-05,
#   "max_position_embeddings": 2048,
#   "model_type": "gpt_neo",
#   "num_heads": 16,
#   "num_layers": 8,
#   "pad_token_id": null,
#   "resid_dropout": 0,
#   "summary_activation": null,
#   "summary_first_dropout": 0.1,
#   "summary_proj_to_labels": true,
#   "summary_type": "cls_index",
#   "summary_use_proj": true,
#   "tie_word_embeddings": true,
#   "transformers_version": "5.15.0",
#   "use_cache": true,
#   "vocab_size": 50257,
#   "window_size": 256
# }

# %%
print(model)
# Out:
# GPTNeoForCausalLM(
#   (transformer): GPTNeoModel(
#     (wte): Embedding(50257, 64)
#     (wpe): Embedding(2048, 64)
#     (drop): Dropout(p=0.0, inplace=False)
#     (h): ModuleList(
#       (0-7): 8 x GPTNeoBlock(
#         (ln_1): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#         (attn): GPTNeoAttention(
#           (attention): GPTNeoSelfAttention(
#             (attn_dropout): Dropout(p=0.0, inplace=False)
#             (resid_dropout): Dropout(p=0.0, inplace=False)
#             (k_proj): Linear(in_features=64, out_features=64, bias=False)
#             (v_proj): Linear(in_features=64, out_features=64, bias=False)
#             (q_proj): Linear(in_features=64, out_features=64, bias=False)
#             (out_proj): Linear(in_features=64, out_features=64, bias=True)
#           )
#         )
#         (ln_2): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#         (mlp): GPTNeoMLP(
#           (c_fc): Linear(in_features=64, out_features=256, bias=True)
#           (c_proj): Linear(in_features=256, out_features=64, bias=True)
#           (act): NewGELUActivation()
#           (dropout): Dropout(p=0.0, inplace=False)
#         )
#       )
#     )
#     (ln_f): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#   )
#   (lm_head): Linear(in_features=64, out_features=50257, bias=False)
# )

# %%
for name, param in model.named_parameters():
    print(name, tuple(param.shape))
# Out:
# transformer.wte.weight (50257, 64)
# transformer.wpe.weight (2048, 64)
# transformer.h.0.ln_1.weight (64,)
# transformer.h.0.ln_1.bias (64,)
# transformer.h.0.attn.attention.k_proj.weight (64, 64)
# transformer.h.0.attn.attention.v_proj.weight (64, 64)
# transformer.h.0.attn.attention.q_proj.weight (64, 64)
# transformer.h.0.attn.attention.out_proj.weight (64, 64)
# transformer.h.0.attn.attention.out_proj.bias (64,)
# transformer.h.0.ln_2.weight (64,)
# transformer.h.0.ln_2.bias (64,)
# transformer.h.0.mlp.c_fc.weight (256, 64)
# transformer.h.0.mlp.c_fc.bias (256,)
# transformer.h.0.mlp.c_proj.weight (64, 256)
# transformer.h.0.mlp.c_proj.bias (64,)
# transformer.h.1.ln_1.weight (64,)
# transformer.h.1.ln_1.bias (64,)
# transformer.h.1.attn.attention.k_proj.weight (64, 64)
# transformer.h.1.attn.attention.v_proj.weight (64, 64)
# transformer.h.1.attn.attention.q_proj.weight (64, 64)
# transformer.h.1.attn.attention.out_proj.weight (64, 64)
# transformer.h.1.attn.attention.out_proj.bias (64,)
# transformer.h.1.ln_2.weight (64,)
# transformer.h.1.ln_2.bias (64,)
# transformer.h.1.mlp.c_fc.weight (256, 64)
# transformer.h.1.mlp.c_fc.bias (256,)
# transformer.h.1.mlp.c_proj.weight (64, 256)
# transformer.h.1.mlp.c_proj.bias (64,)
# transformer.h.2.ln_1.weight (64,)
# transformer.h.2.ln_1.bias (64,)
# transformer.h.2.attn.attention.k_proj.weight (64, 64)
# transformer.h.2.attn.attention.v_proj.weight (64, 64)
# transformer.h.2.attn.attention.q_proj.weight (64, 64)
# transformer.h.2.attn.attention.out_proj.weight (64, 64)
# transformer.h.2.attn.attention.out_proj.bias (64,)
# transformer.h.2.ln_2.weight (64,)
# transformer.h.2.ln_2.bias (64,)
# transformer.h.2.mlp.c_fc.weight (256, 64)
# transformer.h.2.mlp.c_fc.bias (256,)
# transformer.h.2.mlp.c_proj.weight (64, 256)
# transformer.h.2.mlp.c_proj.bias (64,)
# transformer.h.3.ln_1.weight (64,)
# transformer.h.3.ln_1.bias (64,)
# transformer.h.3.attn.attention.k_proj.weight (64, 64)
# transformer.h.3.attn.attention.v_proj.weight (64, 64)
# transformer.h.3.attn.attention.q_proj.weight (64, 64)
# transformer.h.3.attn.attention.out_proj.weight (64, 64)
# transformer.h.3.attn.attention.out_proj.bias (64,)
# transformer.h.3.ln_2.weight (64,)
# transformer.h.3.ln_2.bias (64,)
# transformer.h.3.mlp.c_fc.weight (256, 64)
# transformer.h.3.mlp.c_fc.bias (256,)
# transformer.h.3.mlp.c_proj.weight (64, 256)
# transformer.h.3.mlp.c_proj.bias (64,)
# transformer.h.4.ln_1.weight (64,)
# transformer.h.4.ln_1.bias (64,)
# transformer.h.4.attn.attention.k_proj.weight (64, 64)
# transformer.h.4.attn.attention.v_proj.weight (64, 64)
# transformer.h.4.attn.attention.q_proj.weight (64, 64)
# transformer.h.4.attn.attention.out_proj.weight (64, 64)
# transformer.h.4.attn.attention.out_proj.bias (64,)
# transformer.h.4.ln_2.weight (64,)
# transformer.h.4.ln_2.bias (64,)
# transformer.h.4.mlp.c_fc.weight (256, 64)
# transformer.h.4.mlp.c_fc.bias (256,)
# transformer.h.4.mlp.c_proj.weight (64, 256)
# transformer.h.4.mlp.c_proj.bias (64,)
# transformer.h.5.ln_1.weight (64,)
# transformer.h.5.ln_1.bias (64,)
# transformer.h.5.attn.attention.k_proj.weight (64, 64)
# transformer.h.5.attn.attention.v_proj.weight (64, 64)
# transformer.h.5.attn.attention.q_proj.weight (64, 64)
# transformer.h.5.attn.attention.out_proj.weight (64, 64)
# transformer.h.5.attn.attention.out_proj.bias (64,)
# transformer.h.5.ln_2.weight (64,)
# transformer.h.5.ln_2.bias (64,)
# transformer.h.5.mlp.c_fc.weight (256, 64)
# transformer.h.5.mlp.c_fc.bias (256,)
# transformer.h.5.mlp.c_proj.weight (64, 256)
# transformer.h.5.mlp.c_proj.bias (64,)
# transformer.h.6.ln_1.weight (64,)
# transformer.h.6.ln_1.bias (64,)
# transformer.h.6.attn.attention.k_proj.weight (64, 64)
# transformer.h.6.attn.attention.v_proj.weight (64, 64)
# transformer.h.6.attn.attention.q_proj.weight (64, 64)
# transformer.h.6.attn.attention.out_proj.weight (64, 64)
# transformer.h.6.attn.attention.out_proj.bias (64,)
# transformer.h.6.ln_2.weight (64,)
# transformer.h.6.ln_2.bias (64,)
# transformer.h.6.mlp.c_fc.weight (256, 64)
# transformer.h.6.mlp.c_fc.bias (256,)
# transformer.h.6.mlp.c_proj.weight (64, 256)
# transformer.h.6.mlp.c_proj.bias (64,)
# transformer.h.7.ln_1.weight (64,)
# transformer.h.7.ln_1.bias (64,)
# transformer.h.7.attn.attention.k_proj.weight (64, 64)
# transformer.h.7.attn.attention.v_proj.weight (64, 64)
# transformer.h.7.attn.attention.q_proj.weight (64, 64)
# transformer.h.7.attn.attention.out_proj.weight (64, 64)
# transformer.h.7.attn.attention.out_proj.bias (64,)
# transformer.h.7.ln_2.weight (64,)
# transformer.h.7.ln_2.bias (64,)
# transformer.h.7.mlp.c_fc.weight (256, 64)
# transformer.h.7.mlp.c_fc.bias (256,)
# transformer.h.7.mlp.c_proj.weight (64, 256)
# transformer.h.7.mlp.c_proj.bias (64,)
# transformer.ln_f.weight (64,)
# transformer.ln_f.bias (64,)
